# %% [markdown]
# N.B. Grover's algorithm does not work for systems of only one qubit.

# %%
from qiskit import QuantumCircuit

# %%
oracle=QuantumCircuit(1)
oracle.x(0)
oracle.z(0)
oracle.x(0)
oracle.draw('mpl')

# %%
from qiskit.circuit.library import GroverOperator
grover=GroverOperator(oracle)
grover.draw('mpl')

# %%
init=QuantumCircuit(1)
init.h(0)
qc=init.compose(grover)
qc.measure_all()
qc.draw('mpl')

# %% [markdown]
# Note: the following code can be used for systems of any size with no modification needed.

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
sim=AerSimulator()
t_qc=transpile(qc,sim)

#Plot results
from qiskit.visualization import plot_histogram
plot_histogram(sim.run(t_qc).result().get_counts())

# %% [markdown]
# Note: grovers algorithm doesn't work with just one qubit
